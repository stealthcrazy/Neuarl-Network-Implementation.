# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



df = pd.read_csv('train.csv')

td = df.to_numpy()

# %%
print(td.shape)
# Out:
# (239999, 785)

# %%
imgd = td[0][1:].reshape(28,28)
imgd = np.rot90(imgd)
lbl = td[0][0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 imgd = td[0][1:].reshape(28,28).rot90()
#       3 lbl = td[0][0]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'rot90'

# %%
print(imgd.shape , lbl)
# Out:
# (28, 28) 9

# %%
plt.imshow(imgd , cmap="grey")
